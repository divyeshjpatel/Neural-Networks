# %% [markdown]
# # Gas Turbines

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('D:/ExcelR/A16 neural networks/gas_turbines.csv')

# %%
dataset.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
fig2, axes2 = plt.subplots(1, 2, figsize=(10,4))
sns.scatterplot(data=dataset,y='TEY',x='NOX',ax=axes2[0])
sns.histplot(data=dataset,x='TEY',ax=axes2[1])
# Out:
# <AxesSubplot:xlabel='TEY', ylabel='Count'>

# %%
fig, axes = plt.subplots(3, 3, figsize=(9,9))
sns.scatterplot(data=dataset,y='TEY',x='AT',ax=axes[0,0])
sns.scatterplot(data=dataset,y='TEY',x='AP',ax=axes[0,1])
sns.scatterplot(data=dataset,y='TEY',x='AH',ax=axes[0,2])
sns.scatterplot(data=dataset,y='TEY',x='AFDP',ax=axes[1,0])
sns.scatterplot(data=dataset,y='TEY',x='GTEP',ax=axes[1,1])
sns.scatterplot(data=dataset,y='TEY',x='TIT',ax=axes[1,2])
sns.scatterplot(data=dataset,y='TEY',x='TAT',ax=axes[2,0])
sns.scatterplot(data=dataset,y='TEY',x='CDP',ax=axes[2,1])
sns.scatterplot(data=dataset,y='TEY',x='CO',ax=axes[2,2])
# Out:
# <AxesSubplot:xlabel='CO', ylabel='TEY'>

# %%
X = dataset.iloc[:, [0,1,2,3,4,5,6,8,9,10]].values
y = dataset.iloc[:, 7].values

# %%
print(X)
# Out:
# [[   6.8594 1007.9      96.799  ...   10.605     3.1547   82.722 ]
#  [   6.785  1008.4      97.118  ...   10.598     3.2363   82.776 ]
#  [   6.8977 1008.8      95.939  ...   10.601     3.2012   82.468 ]
#  ...
#  [   7.2647 1006.3      99.496  ...   10.483     7.9632   90.912 ]
#  [   7.006  1006.8      99.008  ...   10.533     6.2494   93.227 ]
#  [   6.9279 1007.2      97.533  ...   10.583     4.9816   92.498 ]]

# %%
print(y)
# Out:
# [114.7  114.72 114.71 ... 110.19 110.74 111.58]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# ## Building and Training ANN

# %%
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=8, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=8, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=1))

# %%
ann.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
ann.fit(X_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 353/353 [==============================] - 1s 1ms/step - loss: 147.1133
# Epoch 2/100
# 353/353 [==============================] - 0s 1ms/step - loss: 111.5169
# Epoch 3/100
# 353/353 [==============================] - 1s 2ms/step - loss: 71.1142
# Epoch 4/100
# 353/353 [==============================] - 0s 1ms/step - loss: 31.8672
# Epoch 5/100
# 353/353 [==============================] - 0s 931us/step - loss: 11.2076
# Epoch 6/100
# 353/353 [==============================] - 0s 943us/step - loss: 5.8812
# Epoch 7/100
# 353/353 [==============================] - 0s 1ms/step - loss: 4.8630
# Epoch 8/100
# 353/353 [==============================] - 0s 960us/step - loss: 4.4537
# Epoch 9/100
# 353/353 [==============================] - 0s 973us/step - loss: 4.1518
# Epoch 10/100
# 353/353 [==============================] - 0s 955us/step - loss: 3.9039
# Epoch 11/100
# 353/353 [==============================] - 0s 953us/step - loss: 3.6027
# Epoch 12/100
# ...

# %% [markdown]
# ## Testing ANN

# %%
y_pred = ann.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[134.06 134.06]
#  [156.77 155.98]
#  [133.41 133.77]
#  ...
#  [109.64 110.15]
#  [134.49 135.48]
#  [155.89 156.21]]
